# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df=pd.read_csv("Costomer+OrderForm.csv")
df
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
defect_1=df['Phillippines']
defect_2=df['Indonesia']
defect_3=df['Malta']
defect_4=df['India']
defect_1
# Out:
# 0      Error Free
# 1      Error Free
# 2      Error Free
# 3      Error Free
# 4      Error Free
#           ...
# 295    Error Free
# 296    Error Free
# 297    Error Free
# 298    Error Free
# 299    Error Free
# Name: Phillippines, Length: 300, dtype: object

# %%
a=0
b=0
for i in defect_1:
  if(i=="Defective"):
    a=a+1
  else:
    b=b+1
print(a,b)
# Out:
# 29 271

# %%
a=0
b=0
for i in defect_2:
  if(i=="Defective"):
    a=a+1
  else:
    b=b+1
print(a,b)
# Out:
# 33 267

# %%
a=0
b=0
for i in defect_3:
  if(i=="Defective"):
    a=a+1
  else:
    b=b+1
print(a,b)
# Out:
# 31 269

# %%
a=0
b=0
for i in defect_4:
  if(i=="Defective"):
    a=a+1
  else:
    b=b+1
print(a,b)
# Out:
# 20 280

# %%
name=['Phillippines','Indonesia','Malta','India']
defective=[29,33,31,20]
error_free=[271,267,269,280]

# %%
data = {'Name': name, 'defective': defective,'error_free':error_free}
df = pd.DataFrame(data)
df
# Out:
#            Name  defective  error_free
# 0  Phillippines         29         271
# 1     Indonesia         33         267
# 2         Malta         31         269
# 3         India         20         280

# %%
defective1=df['defective']
print(defective1.mean())
print(round(defective1.std(),2))
# Out:
# 28.25
# 5.74

# %%
error_free1=df['error_free']
print(error_free1.mean())
print(round(error_free1.std(),2))
# Out:
# 271.75
# 5.74

# %%
#t_statistic,p_value=stats.ttest.ind
t_statistics,p_values=stats.ttest_ind(defective1,error_free1)
p_values
# Out:
# 1.437376025121072e-09

# %%
if p_values<0.05:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# reject null hypothesis
